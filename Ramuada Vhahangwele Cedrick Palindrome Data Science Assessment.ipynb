# %% [markdown]
# #   Ramuada Vhahangwele Cedrick  :Palindrome Data Science Assignment

# %% [markdown]
# #### Import the libraries

# %%
import  pandas as pd 
import  numpy as  np
from matplotlib import  pylab as plt

# %%
data=pd.read_excel("pone.0212445.s004.xlsx")

# %%
data
# Out:
#     S4 Table.  Direct survey domain and "Fay-Heriott" small area estimates of HIV prevalence and the numbers of people living with HIV (NoPLHIV) in the districts of South Africa obtained from Model 3.  LCL and UCL denotes the lower and upper limits, respectively, of 95% confidence intervals.  \
# 0                                             District
# 1                                         Buffalo City
# 2                                         Buffalo City
# 3                                    City of Cape Town
# 4                                    City of Cape Town
# 5                                           West Coast
# 6                                           West Coast
# 7                                               Cacadu
# 8                                               Cacadu
# 9                                              Amatole
# 10                                             Amatole
# 11                                          Chris Hani
# ...

# %% [markdown]
# # data

# %%
data=pd.read_excel("pone.0212445.s004.xlsx",header=None)
data
# Out:
#                                                      0     1            2  \
# 0    S4 Table.  Direct survey domain and "Fay-Herio...   NaN          NaN
# 1                                             District  Code     Estimate
# 2                                         Buffalo City   BUF       Survey
# 3                                         Buffalo City   BUF  Fay-Heriott
# 4                                    City of Cape Town   CPT       Survey
# 5                                    City of Cape Town   CPT  Fay-Heriott
# 6                                           West Coast   DC1       Survey
# 7                                           West Coast   DC1  Fay-Heriott
# 8                                               Cacadu  DC10       Survey
# 9                                               Cacadu  DC10  Fay-Heriott
# 10                                             Amatole  DC12       Survey
# 11                                             Amatole  DC12  Fay-Heriott
# ...

# %% [markdown]
# ## We have  some couple of  option to clean the data

# %% [markdown]
# ### 1.1  option one

# %%
data=pd.read_excel("pone.0212445.s004.xlsx",header=None)

# %%
data = data.iloc[2:,:].set_axis(list(data.iloc[1,:].values), axis=1, inplace=False)

# %%
data
# Out:
#                      District  Code     Estimate Prevalence_% Prevalence_LCL  \
# 2                Buffalo City   BUF       Survey         13.6         10.268
# 3                Buffalo City   BUF  Fay-Heriott      13.5013        11.0316
# 4           City of Cape Town   CPT       Survey          5.2          3.044
# 5           City of Cape Town   CPT  Fay-Heriott      6.02004        4.33507
# 6                  West Coast   DC1       Survey          2.7              0
# 7                  West Coast   DC1  Fay-Heriott      4.08832        2.41435
# 8                      Cacadu  DC10       Survey          7.6          3.484
# 9                      Cacadu  DC10  Fay-Heriott      8.91239        6.14501
# 10                    Amatole  DC12       Survey           11          7.276
# 11                    Amatole  DC12  Fay-Heriott      11.8786         9.0907
# 12                 Chris Hani  DC13       Survey         14.3         10.184
# ...

# %%
data=data.reset_index(drop=True)#Resetting the index

# %%
data
# Out:
#                      District  Code     Estimate Prevalence_% Prevalence_LCL  \
# 0                Buffalo City   BUF       Survey         13.6         10.268
# 1                Buffalo City   BUF  Fay-Heriott      13.5013        11.0316
# 2           City of Cape Town   CPT       Survey          5.2          3.044
# 3           City of Cape Town   CPT  Fay-Heriott      6.02004        4.33507
# 4                  West Coast   DC1       Survey          2.7              0
# 5                  West Coast   DC1  Fay-Heriott      4.08832        2.41435
# 6                      Cacadu  DC10       Survey          7.6          3.484
# 7                      Cacadu  DC10  Fay-Heriott      8.91239        6.14501
# 8                     Amatole  DC12       Survey           11          7.276
# 9                     Amatole  DC12  Fay-Heriott      11.8786         9.0907
# 10                 Chris Hani  DC13       Survey         14.3         10.184
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 9 columns):
# District          104 non-null object
# Code              104 non-null object
# Estimate          104 non-null object
# Prevalence_%      104 non-null object
# Prevalence_LCL    104 non-null object
# Prevalence_UCL    104 non-null object
# NoPLHIV           104 non-null object
# NoPLHIV_LCL       104 non-null object
# NoPLHIV_UCL       104 non-null object
# dtypes: object(9)
# memory usage: 7.4+ KB

# %%
data.describe()#Statistics  for data
# Out:
#        District  Code Estimate  Prevalence_%  Prevalence_LCL  Prevalence_UCL  \
# count       104   104      104         104.0           104.0      104.000000
# unique       52    52        2          98.0           103.0      104.000000
# top         Ugu  DC40   Survey          14.3             0.0        8.303091
# freq          2     2       52           2.0             2.0        1.000000
#
#         NoPLHIV  NoPLHIV_LCL  NoPLHIV_UCL
# count       104          104          104
# unique      104          103          104
# top      123131            0       278847
# freq          1            2            1

# %% [markdown]
# From the results we see  that only district , code and estimate are  not numeric and  the others are numeric and their type is object so we need  to cast them to numeric

# %% [markdown]
# ## 1.2  Resolving the type problem

# %% [markdown]
# We can resolve this problem using using the built in function called   infer_objects to deal with the problem or
# we can cast columns ourselves

# %% [markdown]
# ### 1.2.1  Using the  infer_objects

# %%
fl=data.copy()

# %% [markdown]
# %%timeit   method estimates how fast the code executes

# %%
# %%timeit
fl=data.copy()
fl=fl.infer_objects()
# Out:
# The slowest run took 11.54 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100 loops, best of 3: 3.23 ms per loop

# %%
fl=data.copy()
fl=fl.infer_objects()
fl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 9 columns):
# District          104 non-null object
# Code              104 non-null object
# Estimate          104 non-null object
# Prevalence_%      104 non-null float64
# Prevalence_LCL    104 non-null float64
# Prevalence_UCL    104 non-null float64
# NoPLHIV           104 non-null int64
# NoPLHIV_LCL       104 non-null int64
# NoPLHIV_UCL       104 non-null int64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 7.4+ KB

# %% [markdown]
# From the above results we can see that the problem is resolved, but let's also try to use another method

# %%
data.columns
# Out:
# Index([u'District', u'Code', u'Estimate', u'Prevalence_%', u'Prevalence_LCL',
#        u'Prevalence_UCL', u'NoPLHIV', u'NoPLHIV_LCL', u'NoPLHIV_UCL'],
#       dtype='object')

# %% [markdown]
# ## 1.2.2   dictionary data type conversion

# %%
# %%timeit
#display(data.dtypes)
# Out:
# 10000000 loops, best of 3: 19 ns per loop

# %%
from IPython.display import display
display(data.dtypes)
# Out:
# District          object
# Code              object
# Estimate          object
# Prevalence_%      object
# Prevalence_LCL    object
# Prevalence_UCL    object
# NoPLHIV           object
# NoPLHIV_LCL       object
# NoPLHIV_UCL       object
# dtype: object

# %%
# %%timeit

df=data.copy()
data_type_convertion = {'Prevalence_%': float, 'Prevalence_LCL': float,
                'Prevalence_UCL':  float,'NoPLHIV':int, 'NoPLHIV_LCL':int, 'NoPLHIV_UCL':int
                }
  
df = df.astype(data_type_convertion)
display(df.dtypes)
# Out:
# District           object
# Code               object
# Estimate           object
# Prevalence_%      float64
# Prevalence_LCL    float64
# Prevalence_UCL    float64
# NoPLHIV             int64
# NoPLHIV_LCL         int64
# NoPLHIV_UCL         int64
# dtype: object
# District           object
# Code               object
# Estimate           object
# Prevalence_%      float64
# Prevalence_LCL    float64
# Prevalence_UCL    float64
# NoPLHIV             int64
# NoPLHIV_LCL         int64
# NoPLHIV_UCL         int64
# dtype: object
# District           object
# Code               object
# Estimate           object
# Prevalence_%      float64
# Prevalence_LCL    float64
# Prevalence_UCL    float64
# NoPLHIV             int64
# NoPLHIV_LCL         int64
# NoPLHIV_UCL         int64
# dtype: object
# District           object
# Code               object
# Estimate           object
# Prevalence_%      float64
# Prevalence_LCL    float64
# Prevalence_UCL    float64
# NoPLHIV             int64
# ...

# %% [markdown]
# I will stick with the first option since it doesnot consume alot of time to execute, however it does consume alot of space in memory but this is not our main concern for now since the differecne is very minimal

# %%
dt=data.copy()

dt=dt.infer_objects()

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 9 columns):
# District          104 non-null object
# Code              104 non-null object
# Estimate          104 non-null object
# Prevalence_%      104 non-null float64
# Prevalence_LCL    104 non-null float64
# Prevalence_UCL    104 non-null float64
# NoPLHIV           104 non-null int64
# NoPLHIV_LCL       104 non-null int64
# NoPLHIV_UCL       104 non-null int64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 7.4+ KB

# %% [markdown]
# ##   Question 2 (a) What is the total number of people living with HIV (NoPLHIV) in the listed districts according to the Survey estimate?

# %% [markdown]
# 1.1 option  1

# %%
q1_answer1=pd.DataFrame(dt.groupby(["District"])["NoPLHIV"].sum()).reset_index(level=0)
q1_answer1
# Out:
#                      District  NoPLHIV
# 0                  Alfred Nzo   209508
# 1                     Amajuba   163220
# 2                     Amatole   205667
# 3           Bojanala Platinum   425631
# 4                Buffalo City   204130
# 5                      Cacadu    75461
# 6              Cape Winelands    75359
# 7                   Capricorn   239482
# 8               Central Karoo    26398
# 9                  Chris Hani   227939
# 10          City of Cape Town   433160
# 11       City of Johannesburg  1029628
# 12            City of Tshwane   702043
# 13          Dr Kenneth Kaunda   202515
# 14  Dr Ruth Segomotsi Mompati   103586
# 15                       Eden    56342
# 16                  Ehlanzeni   552283
# 17                 Ekurhuleni   904049
# 18                Fezile Dabi    96317
# 19              Frances Baard    88205
# 20               Gert Sibande   415124
# 21                  Joe Gqabi    78384
# 22        John Taolo Gaetsewe    38769
# ...

# %%
#Multi index
dt.groupby(['District'])[["NoPLHIV"]].agg("sum")
# Out:
#                            NoPLHIV
# District
# Alfred Nzo                  209508
# Amajuba                     163220
# Amatole                     205667
# Bojanala Platinum           425631
# Buffalo City                204130
# Cacadu                       75461
# Cape Winelands               75359
# Capricorn                   239482
# Central Karoo                26398
# Chris Hani                  227939
# City of Cape Town           433160
# City of Johannesburg       1029628
# City of Tshwane             702043
# Dr Kenneth Kaunda           202515
# Dr Ruth Segomotsi Mompati   103586
# Eden                         56342
# Ehlanzeni                   552283
# Ekurhuleni                  904049
# Fezile Dabi                  96317
# Frances Baard                88205
# Gert Sibande                415124
# Joe Gqabi                    78384
# John Taolo Gaetsewe          38769
# Lejweleputswa               231434
# Mangaung                    189196
# ...

# %%
# %timeit
q1_answer2=data.groupby(['District'])[["NoPLHIV"]].agg("sum").reset_index(level=0)
q1_answer2
# Out:
#                      District  NoPLHIV
# 0                  Alfred Nzo   209508
# 1                     Amajuba   163220
# 2                     Amatole   205667
# 3           Bojanala Platinum   425631
# 4                Buffalo City   204130
# 5                      Cacadu    75461
# 6              Cape Winelands    75359
# 7                   Capricorn   239482
# 8               Central Karoo    26398
# 9                  Chris Hani   227939
# 10          City of Cape Town   433160
# 11       City of Johannesburg  1029628
# 12            City of Tshwane   702043
# 13          Dr Kenneth Kaunda   202515
# 14  Dr Ruth Segomotsi Mompati   103586
# 15                       Eden    56342
# 16                  Ehlanzeni   552283
# 17                 Ekurhuleni   904049
# 18                Fezile Dabi    96317
# 19              Frances Baard    88205
# 20               Gert Sibande   415124
# 21                  Joe Gqabi    78384
# 22        John Taolo Gaetsewe    38769
# ...

# %%
q1_answer2=data.groupby(['District'])[["NoPLHIV"]].agg("sum").reset_index(level=0)
q1_answer2
# Out:
#                      District  NoPLHIV
# 0                  Alfred Nzo   209508
# 1                     Amajuba   163220
# 2                     Amatole   205667
# 3           Bojanala Platinum   425631
# 4                Buffalo City   204130
# 5                      Cacadu    75461
# 6              Cape Winelands    75359
# 7                   Capricorn   239482
# 8               Central Karoo    26398
# 9                  Chris Hani   227939
# 10          City of Cape Town   433160
# 11       City of Johannesburg  1029628
# 12            City of Tshwane   702043
# 13          Dr Kenneth Kaunda   202515
# 14  Dr Ruth Segomotsi Mompati   103586
# 15                       Eden    56342
# 16                  Ehlanzeni   552283
# 17                 Ekurhuleni   904049
# 18                Fezile Dabi    96317
# 19              Frances Baard    88205
# 20               Gert Sibande   415124
# 21                  Joe Gqabi    78384
# 22        John Taolo Gaetsewe    38769
# ...

# %%
# %%timeit
q1_answer3=dt.groupby('District')[["NoPLHIV"]].apply(np.sum).reset_index(level=0)
q1_answer3
# Out:
# 10 loops, best of 3: 40 ms per loop

# %%
q1_answer3=dt.groupby('District')[["NoPLHIV"]].apply(np.sum).reset_index(level=0)
q1_answer3
# Out:
#                      District  NoPLHIV
# 0                  Alfred Nzo   209508
# 1                     Amajuba   163220
# 2                     Amatole   205667
# 3           Bojanala Platinum   425631
# 4                Buffalo City   204130
# 5                      Cacadu    75461
# 6              Cape Winelands    75359
# 7                   Capricorn   239482
# 8               Central Karoo    26398
# 9                  Chris Hani   227939
# 10          City of Cape Town   433160
# 11       City of Johannesburg  1029628
# 12            City of Tshwane   702043
# 13          Dr Kenneth Kaunda   202515
# 14  Dr Ruth Segomotsi Mompati   103586
# 15                       Eden    56342
# 16                  Ehlanzeni   552283
# 17                 Ekurhuleni   904049
# 18                Fezile Dabi    96317
# 19              Frances Baard    88205
# 20               Gert Sibande   415124
# 21                  Joe Gqabi    78384
# 22        John Taolo Gaetsewe    38769
# ...

# %%
# Out:
#                      District  NoPLHIV
# 0                  Alfred Nzo   209508
# 1                     Amajuba   163220
# 2                     Amatole   205667
# 3           Bojanala Platinum   425631
# 4                Buffalo City   204130
# 5                      Cacadu    75461
# 6              Cape Winelands    75359
# 7                   Capricorn   239482
# 8               Central Karoo    26398
# 9                  Chris Hani   227939
# 10          City of Cape Town   433160
# 11       City of Johannesburg  1029628
# 12            City of Tshwane   702043
# 13          Dr Kenneth Kaunda   202515
# 14  Dr Ruth Segomotsi Mompati   103586
# 15                       Eden    56342
# 16                  Ehlanzeni   552283
# 17                 Ekurhuleni   904049
# 18                Fezile Dabi    96317
# 19              Frances Baard    88205
# 20               Gert Sibande   415124
# 21                  Joe Gqabi    78384
# 22        John Taolo Gaetsewe    38769
# ...

# %% [markdown]
# ## Question 2  (b)  What is the average NoPLHIV of the two estimates used for “Xhariep”?

# %%
## option1

# %%
data["District"].unique()
# Out:
# array([u'Buffalo City', u'City of Cape Town', u'West Coast', u'Cacadu',
#        u'Amatole', u'Chris Hani', u'Joe Gqabi', u'O.R. Tambo', u'Xhariep',
#        u'Lejweleputswa', u'Thabo Mofutsanyana', u'Cape Winelands',
#        u'Fezile Dabi', u'Ugu', u'uMgungundlovu', u'uThukela',
#        u'uMzinyathi', u'Amajuba', u'Zululand', u'uMkhanyakude',
#        u'uThungulu', u'iLembe', u'Overberg', u'Gert Sibande', u'Nkangala',
#        u'Ehlanzeni', u'Mopani', u'Vhembe', u'Capricorn', u'Waterberg',
#        u'Bojanala Platinum', u'Ngaka Modiri Molema',
#        u'Dr Ruth Segomotsi Mompati', u'Eden', u'Dr Kenneth Kaunda',
#        u'Sedibeng', u'Sisonke', u'Alfred Nzo', u'John Taolo Gaetsewe',
#        u'Sekhukhune', u'West Rand', u'Central Karoo', u'Namakwa',
#        u'Pixley ka Seme', u'Siyanda', u'Frances Baard', u'Ekurhuleni',
#        u'eThekwini', u'City of Johannesburg', u'Mangaung',
#        u'Nelson Mandela Bay Metro', u'City of Tshwane'], dtype=object)

# %%
data[data["District"]=="Xhariep"]
# Out:
#    District  Code     Estimate Prevalence_% Prevalence_LCL Prevalence_UCL  \
# 16  Xhariep  DC16       Survey          8.3          6.144         10.456
# 17  Xhariep  DC16  Fay-Heriott      8.96307        7.18782        11.1242
#
#    NoPLHIV NoPLHIV_LCL NoPLHIV_UCL
# 16   11777        8718       14836
# 17   12718       10199       15784

# %%
# %%timeit
q2_option2=dt[dt.District.isin(['Xhariep'])].groupby("District")["NoPLHIV"].mean().reset_index(level=0)
# Out:
# 100 loops, best of 3: 5.65 ms per loop

# %%
q2_option2=dt[dt.District.isin(['Xhariep'])].groupby("District")["NoPLHIV"].mean().reset_index(level=0)
q2_option2
# Out:
#   District  NoPLHIV
# 0  Xhariep  12247.5

# %%
# %%timeit
q2_option3=dt.loc[(dt.District == "Xhariep")].groupby("District")["NoPLHIV"].mean().reset_index(level=0)
# Out:
# The slowest run took 4.28 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100 loops, best of 3: 5.86 ms per loop

# %%
q2_option3=dt.loc[(dt.District == "Xhariep")].groupby("District")["NoPLHIV"].mean().reset_index(level=0)
q2_option3
# Out:
#   District  NoPLHIV
# 0  Xhariep  12247.5

# %%
# %%timeit
q2_option5= dt[dt.apply(lambda x: x["District"] == 'Xhariep', axis=1)].groupby("District")["NoPLHIV"].mean().reset_index(level=0)
# Out:
# The slowest run took 6.53 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100 loops, best of 3: 11.1 ms per loop

# %%
q2_option5= dt[dt.apply(lambda x: x["District"] == 'Xhariep', axis=1)].groupby("District")["NoPLHIV"].mean().reset_index(level=0)
q2_option5
# Out:
#   District  NoPLHIV
# 0  Xhariep  12247.5

# %%
# %%timeit
q2_option6 = dt.iloc[[index for index,row in df.iterrows() if row['District'] == 'Xhariep']].groupby("District")["NoPLHIV"].mean().reset_index(level=0)
# Out:
# 10 loops, best of 3: 32.4 ms per loop

# %%
q2_option6 = dt.iloc[[index for index,row in df.iterrows() if row['District'] == 'Xhariep']].groupby("District")["NoPLHIV"].mean().reset_index(level=0)
q2_option6
# Out:
#   District  NoPLHIV
# 0  Xhariep  12247.5

# %% [markdown]
# I chose   option one  because it  is faster and  easy to change, and it is the most common practise and it would be
# easier for some one to read and change the code accordingly

# %% [markdown]
# ##  Question 2 (c)  Add a column and populate it with the number of people not living with HIV for each row.

# %%
data
# Out:
#                      District  Code     Estimate Prevalence_% Prevalence_LCL  \
# 0                Buffalo City   BUF       Survey         13.6         10.268
# 1                Buffalo City   BUF  Fay-Heriott      13.5013        11.0316
# 2           City of Cape Town   CPT       Survey          5.2          3.044
# 3           City of Cape Town   CPT  Fay-Heriott      6.02004        4.33507
# 4                  West Coast   DC1       Survey          2.7              0
# 5                  West Coast   DC1  Fay-Heriott      4.08832        2.41435
# 6                      Cacadu  DC10       Survey          7.6          3.484
# 7                      Cacadu  DC10  Fay-Heriott      8.91239        6.14501
# 8                     Amatole  DC12       Survey           11          7.276
# 9                     Amatole  DC12  Fay-Heriott      11.8786         9.0907
# 10                 Chris Hani  DC13       Survey         14.3         10.184
# ...

# %%
def  non_infect(x,r):
    r=r/100
    y=(x/r)*(1-r)
    return int(y)

# %%
pd.reset_option('precision')

# %%
data.columns
# Out:
# Index([u'District', u'Code', u'Estimate', u'Prevalence_%', u'Prevalence_LCL',
#        u'Prevalence_UCL', u'NoPLHIV', u'NoPLHIV_LCL', u'NoPLHIV_UCL'],
#       dtype='object')

# %%
dt["No_NON_HIV_PPL"]=pd.to_numeric(dt.apply(lambda row : non_infect(row['NoPLHIV'],
                        row['Prevalence_%']), axis = 1),downcast='integer')

# %%
q3_option1=dt.copy()
q3_option1["No_NON_HIV_PPL"]=pd.to_numeric(dt.apply(lambda row : non_infect(row['NoPLHIV'],
                        row['Prevalence_%']), axis = 1),downcast='integer')

# %%
q3_option1=dt.copy()
q3_option1
# Out:
#                      District  Code     Estimate  Prevalence_%  \
# 0                Buffalo City   BUF       Survey     13.600000
# 1                Buffalo City   BUF  Fay-Heriott     13.501283
# 2           City of Cape Town   CPT       Survey      5.200000
# 3           City of Cape Town   CPT  Fay-Heriott      6.020043
# 4                  West Coast   DC1       Survey      2.700000
# 5                  West Coast   DC1  Fay-Heriott      4.088319
# 6                      Cacadu  DC10       Survey      7.600000
# 7                      Cacadu  DC10  Fay-Heriott      8.912387
# 8                     Amatole  DC12       Survey     11.000000
# 9                     Amatole  DC12  Fay-Heriott     11.878608
# 10                 Chris Hani  DC13       Survey     14.300000
# 11                 Chris Hani  DC13  Fay-Heriott     14.080983
# 12                  Joe Gqabi  DC14       Survey     10.700000
# 13                  Joe Gqabi  DC14  Fay-Heriott     11.507804
# ...

# %% [markdown]
# ##  Question 2 (d) What is the total NoPLHIV in all the cities (districts with “city” or “metro” in the name)?

# %%
data["District"].unique()
# Out:
# array([u'Buffalo City', u'City of Cape Town', u'West Coast', u'Cacadu',
#        u'Amatole', u'Chris Hani', u'Joe Gqabi', u'O.R. Tambo', u'Xhariep',
#        u'Lejweleputswa', u'Thabo Mofutsanyana', u'Cape Winelands',
#        u'Fezile Dabi', u'Ugu', u'uMgungundlovu', u'uThukela',
#        u'uMzinyathi', u'Amajuba', u'Zululand', u'uMkhanyakude',
#        u'uThungulu', u'iLembe', u'Overberg', u'Gert Sibande', u'Nkangala',
#        u'Ehlanzeni', u'Mopani', u'Vhembe', u'Capricorn', u'Waterberg',
#        u'Bojanala Platinum', u'Ngaka Modiri Molema',
#        u'Dr Ruth Segomotsi Mompati', u'Eden', u'Dr Kenneth Kaunda',
#        u'Sedibeng', u'Sisonke', u'Alfred Nzo', u'John Taolo Gaetsewe',
#        u'Sekhukhune', u'West Rand', u'Central Karoo', u'Namakwa',
#        u'Pixley ka Seme', u'Siyanda', u'Frances Baard', u'Ekurhuleni',
#        u'eThekwini', u'City of Johannesburg', u'Mangaung',
#        u'Nelson Mandela Bay Metro', u'City of Tshwane'], dtype=object)

# %%
data
# Out:
#                      District  Code     Estimate Prevalence_% Prevalence_LCL  \
# 0                Buffalo City   BUF       Survey         13.6         10.268
# 1                Buffalo City   BUF  Fay-Heriott      13.5013        11.0316
# 2           City of Cape Town   CPT       Survey          5.2          3.044
# 3           City of Cape Town   CPT  Fay-Heriott      6.02004        4.33507
# 4                  West Coast   DC1       Survey          2.7              0
# 5                  West Coast   DC1  Fay-Heriott      4.08832        2.41435
# 6                      Cacadu  DC10       Survey          7.6          3.484
# 7                      Cacadu  DC10  Fay-Heriott      8.91239        6.14501
# 8                     Amatole  DC12       Survey           11          7.276
# 9                     Amatole  DC12  Fay-Heriott      11.8786         9.0907
# 10                 Chris Hani  DC13       Survey         14.3         10.184
# ...

# %%
dt[(dt.District.str.contains('City')) |(dt.District.str.contains("Metro"))]
# Out:
#                      District Code     Estimate  Prevalence_%  Prevalence_LCL  \
# 0                Buffalo City  BUF       Survey     13.600000       10.268000
# 1                Buffalo City  BUF  Fay-Heriott     13.501283       11.031605
# 2           City of Cape Town  CPT       Survey      5.200000        3.044000
# 3           City of Cape Town  CPT  Fay-Heriott      6.020043        4.335072
# 96       City of Johannesburg  JHB       Survey     11.100000        7.964000
# 97       City of Johannesburg  JHB  Fay-Heriott     11.075306        8.760104
# 100  Nelson Mandela Bay Metro  NMA       Survey      8.300000        3.400000
# 101  Nelson Mandela Bay Metro  NMA  Fay-Heriott      9.054060        6.128703
# 102           City of Tshwane  TSH       Survey     11.700000        7.388000
# 103           City of Tshwane  TSH  Fay-Heriott     11.024858        8.255934
#
#      Prevalence_UCL  NoPLHIV  NoPLHIV_LCL  NoPLHIV_UCL  No_NON_HIV_PPL
# ...

# %%
# %%timeit
dt[(dt.District.str.contains('City'))|(dt.District.str.contains('Metro'))].groupby("District")["NoPLHIV"].mean().reset_index(level=0)
# Out:
# The slowest run took 13.65 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100 loops, best of 3: 7.4 ms per loop

# %%
q2d_option1=dt[(dt.District.str.contains('City'))|(dt.District.str.contains('Metro'))].groupby("District")["NoPLHIV"].sum().reset_index(level=0)

# %%
q2d_option1
# Out:
#                    District  NoPLHIV
# 0              Buffalo City   204130
# 1         City of Cape Town   433160
# 2      City of Johannesburg  1029628
# 3           City of Tshwane   702043
# 4  Nelson Mandela Bay Metro   203772

# %% [markdown]
# ## Question 3 Remove all the special/non-alphabetic characters from the dataframe column names. Print the resultant field names output.

# %%
dt.columns
# Out:
# Index([      u'District',           u'Code',       u'Estimate',
#          u'Prevalence_%', u'Prevalence_LCL', u'Prevalence_UCL',
#               u'NoPLHIV',    u'NoPLHIV_LCL',    u'NoPLHIV_UCL',
#        u'No_NON_HIV_PPL'],
#       dtype='object')

# %%
cleaned_dc=dt.copy()

# %%
cleaned_dc.columns = cleaned_dc.columns.str.replace(r"[^a-zA-Z\d\_]||\_+", "")

# %%
print("Old column names:")
print(list(dt.columns))
# Out:
# Old column names:
# [u'District', u'Code', u'Estimate', u'Prevalence_%', u'Prevalence_LCL', u'Prevalence_UCL', u'NoPLHIV', u'NoPLHIV_LCL', u'NoPLHIV_UCL', 'No_NON_HIV_PPL']

# %%
print("Cleaned column names:")
print(list(cleaned_dc.columns))
# Out:
# Cleaned column names:
# [u'District', u'Code', u'Estimate', u'Prevalence_', u'Prevalence_LCL', u'Prevalence_UCL', u'NoPLHIV', u'NoPLHIV_LCL', u'NoPLHIV_UCL', 'No_NON_HIV_PPL']

# %% [markdown]
# ## Question 4   Using matplotlib, plot each Prevalence confidence interval (Prevalence_UCL and Prevalence_LCL) for Districts that end in “i”; according to Fay-Herriott estimates on 1 graph.

# %%
q5=cleaned_dc[dt.District.str.endswith('i')]

# %%
q5
# Out:
#                      District  Code     Estimate  Prevalence_  Prevalence_LCL  \
# 10                 Chris Hani  DC13       Survey    14.300000       10.184000
# 11                 Chris Hani  DC13  Fay-Heriott    14.080983       11.181220
# 12                  Joe Gqabi  DC14       Survey    10.700000        7.956000
# 13                  Joe Gqabi  DC14  Fay-Heriott    11.507804        9.291766
# 24                Fezile Dabi  DC20       Survey     9.000000        6.256000
# 25                Fezile Dabi  DC20  Fay-Heriott    10.030754        7.811309
# 32                 uMzinyathi  DC24       Survey    18.200000       16.632000
# 33                 uMzinyathi  DC24  Fay-Heriott    18.097578       16.845087
# 50                  Ehlanzeni  DC32       Survey    16.400000       10.324000
# 51                  Ehlanzeni  DC32  Fay-Heriott    15.820960       12.012425
# 52                     Mopani  DC33       Survey    11.400000        5.520000
# ...

# %%
q5.columns
# Out:
# Index([      u'District',           u'Code',       u'Estimate',
#           u'Prevalence_', u'Prevalence_LCL', u'Prevalence_UCL',
#               u'NoPLHIV',    u'NoPLHIV_LCL',    u'NoPLHIV_UCL',
#        u'No_NON_HIV_PPL'],
#       dtype='object')

# %%
q5["Estimate"].unique()
# Out:
# array([u'Survey', u'Fay-Heriott'], dtype=object)

# %%
data=pd.read_csv("vhahangwele.csv")
data
# Out:
#                     District  Code     Estimate  Prevalence  PrevalenceLCL  \
# 0                 Chris Hani  DC13  Fay-Heriott   14.080983      11.181220
# 1                  Joe Gqabi  DC14  Fay-Heriott   11.507804       9.291766
# 2                Fezile Dabi  DC20  Fay-Heriott   10.030754       7.811309
# 3                 uMzinyathi  DC24  Fay-Heriott   18.097578      16.845087
# 4                  Ehlanzeni  DC32  Fay-Heriott   15.820960      12.012425
# 5                     Mopani  DC33  Fay-Heriott   11.294971       7.921185
# 6  Dr Ruth Segomotsi Mompati  DC39  Fay-Heriott   11.045235       8.164344
# 7                 Ekurhuleni   EKU  Fay-Heriott   13.678908      10.647292
# 8                  eThekwini   ETH  Fay-Heriott   14.537772      11.791222
#
#    PrevalenceUCL
# 0      17.583893
# 1      14.169794
# 2      12.793304
# 3      19.421445
# 4      20.554906
# 5      15.858238
# 6      14.779090
# 7      17.405572
# 8      17.795017

# %%
tempf=data.set_index('District')
#tempf

# %%
#q5.query("`Estimate`== 'Fay-Heriott' ")

# %%
#remove.set_index('District')

# %%
#tempf=temp.set_index('District')

# %%
a=tempf.plot.bar(figsize=(12,10))
plt.show(a)
